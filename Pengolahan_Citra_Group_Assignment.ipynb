# %% [markdown]
# # Import dependencies

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Load Image

# %%
img = cv2.imread('barred-owls.jpg', cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original')
plt.axis('off')
plt.show()

# %% [markdown]
# # Deteksi Tepi

# %%
edges = cv2.Canny(img, 50, 150, apertureSize=3)

plt.figure(figsize=(8,6))
plt.imshow(edges, cmap='gray')
plt.title('Deteksi Tepi')
plt.axis('off')
plt.show()

cv2.imwrite('canny_edges.jpg', edges)
# Out:
# True

# %% [markdown]
# # Operasi Dilation

# %%
kernel = np.ones((3, 3), np.uint8)

dilated_edges = cv2.dilate(edges, kernel, iterations=1)

plt.figure(figsize=(8,6))
plt.imshow(dilated_edges, cmap='gray')
plt.title('Operasi Dilation')
plt.axis('off')
plt.show()

cv2.imwrite('dilated_edges.jpg', dilated_edges)
# Out:
# True

# %% [markdown]
# # Result

# %%
plt.figure(figsize=(12, 6))

plt.subplot(141)
plt.imshow(img, cmap='gray')
plt.title('Original Image')


plt.subplot(142)
plt.imshow(edges, cmap='gray')
plt.title('Edges')

plt.subplot(143)
plt.imshow(dilated_edges, cmap='gray')
plt.title('Dilated Edges')

plt.show()

plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original')
plt.axis('off')
plt.show()

plt.figure(figsize=(8,6))
plt.imshow(edges, cmap='gray')
plt.title('Deteksi Tepi')
plt.axis('off')
plt.show()

plt.figure(figsize=(8,6))
plt.imshow(dilated_edges, cmap='gray')
plt.title('Operasi Dilation')
plt.axis('off')
plt.show()
